# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}" # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}&units=metric" # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"] # YOUR CODE HERE
        city_lng = city_weather["coord"]["lon"]# YOUR CODE HERE
        city_max_temp = city_weather['main']['temp_max'] # YOUR CODE HERE
        city_humidity = city_weather['main']['humidity']# YOUR CODE HERE
        city_clouds = city_weather['clouds']['all']# YOUR CODE HERE
        city_wind = city_weather['wind']['speed']# YOUR CODE HERE
        city_country = city_weather["sys"]['country'] # YOUR CODE HERE
        city_date = city_weather['dt']# YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ugoofaaru
# Processing Record 2 of Set 1 | mhamid
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | enewetak
# Processing Record 5 of Set 1 | wailua homesteads
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | jayapura
# Processing Record 9 of Set 1 | hawaiian paradise park
# Processing Record 10 of Set 1 | aykhal
# Processing Record 11 of Set 1 | seven pagodas
# Processing Record 12 of Set 1 | nagqu
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | port mathurin
# Processing Record 15 of Set 1 | invercargill
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | qaqortoq
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | babat
# Processing Record 21 of Set 1 | luchegorsk
# Processing Record 22 of Set 1 | yaroslavl
# Processing Record 23 of Set 1 | vila franca do campo
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | west island
# Processing Record 26 of Set 1 | atafu village
# Processing Record 27 of Set 1 | fale old settlement
# Processing Record 28 of Set 1 | ulladulla
# Processing Record 29 of Set 1 | klyuchi
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | zeya
# Processing Record 35 of Set 1 | oriximina
# Processing Record 36 of Set 1 | olonkinbyen
# Processing Record 37 of Set 1 | margaret river
# Processing Record 38 of Set 1 | bahia de caraquez
# Processing Record 39 of Set 1 | itoman
# Processing Record 40 of Set 1 | dudinka
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | waingapu
# Processing Record 43 of Set 1 | market shop
# City not found. Skipping...
# Processing Record 44 of Set 1 | kingston
# Processing Record 45 of Set 1 | isafjordur
# Processing Record 46 of Set 1 | codrington
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | baiao
# Processing Record 49 of Set 1 | sinabang
# Processing Record 50 of Set 1 | maridi
# Processing Record 0 of Set 2 | siwa oasis
# Processing Record 1 of Set 2 | puerto natales
# Processing Record 2 of Set 2 | edinburgh of the seven seas
# Processing Record 3 of Set 2 | lihue
# Processing Record 4 of Set 2 | peruibe
# Processing Record 5 of Set 2 | podporozh'ye
# Processing Record 6 of Set 2 | rawson
# Processing Record 7 of Set 2 | tolanaro
# Processing Record 8 of Set 2 | kayan
# Processing Record 9 of Set 2 | larache
# Processing Record 10 of Set 2 | rikaze
# Processing Record 11 of Set 2 | gizo
# Processing Record 12 of Set 2 | uturoa
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | pankrushikha
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | haiku-pauwela
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | lompoc
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | papatowai
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | kailua-kona
# Processing Record 24 of Set 2 | mount gambier
# Processing Record 25 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 2 | ust-nera
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | sidi khaled
# Processing Record 29 of Set 2 | nguigmi
# Processing Record 30 of Set 2 | meybod
# Processing Record 31 of Set 2 | pemangkat
# Processing Record 32 of Set 2 | luena
# Processing Record 33 of Set 2 | kuching
# Processing Record 34 of Set 2 | howard springs
# Processing Record 35 of Set 2 | vadso
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | wagar
# Processing Record 38 of Set 2 | maumere
# Processing Record 39 of Set 2 | cestos city
# Processing Record 40 of Set 2 | labrador city
# Processing Record 41 of Set 2 | parabel'
# Processing Record 42 of Set 2 | khandyga
# Processing Record 43 of Set 2 | kindu
# Processing Record 44 of Set 2 | kerikeri
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | oualidia
# City not found. Skipping...
# Processing Record 47 of Set 2 | ordos
# City not found. Skipping...
# Processing Record 48 of Set 2 | east london
# Processing Record 49 of Set 2 | kavieng
# Processing Record 0 of Set 3 | el calafate
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | saynshand
# Processing Record 3 of Set 3 | bridlington
# Processing Record 4 of Set 3 | ejido
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | port lincoln
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | caribou
# Processing Record 9 of Set 3 | aguada de pasajeros
# Processing Record 10 of Set 3 | baranchinskiy
# Processing Record 11 of Set 3 | naze
# Processing Record 12 of Set 3 | kristinestad
# Processing Record 13 of Set 3 | konarka
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | yangambi
# Processing Record 16 of Set 3 | torghay
# Processing Record 17 of Set 3 | labytnangi
# Processing Record 18 of Set 3 | malvan
# Processing Record 19 of Set 3 | chonchi
# Processing Record 20 of Set 3 | al 'aziziyah
# Processing Record 21 of Set 3 | tobelo
# Processing Record 22 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 3 | glace bay
# Processing Record 24 of Set 3 | port saint john's
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | taroa
# Processing Record 27 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 28 of Set 3 | fuerte olimpo
# Processing Record 29 of Set 3 | puerto san jose
# Processing Record 30 of Set 3 | hausjarvi
# Processing Record 31 of Set 3 | minas de marcona
# Processing Record 32 of Set 3 | udachny
# Processing Record 33 of Set 3 | badger
# Processing Record 34 of Set 3 | grajau
# Processing Record 35 of Set 3 | isabela
# Processing Record 36 of Set 3 | nemuro
# Processing Record 37 of Set 3 | baraki barak
# Processing Record 38 of Set 3 | kargil
# Processing Record 39 of Set 3 | crane
# Processing Record 40 of Set 3 | praia
# Processing Record 41 of Set 3 | utrik
# Processing Record 42 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 43 of Set 3 | fuyang
# Processing Record 44 of Set 3 | greenville
# Processing Record 45 of Set 3 | menongue
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | gilgit
# Processing Record 48 of Set 3 | carutapera
# Processing Record 49 of Set 3 | terekli-mekteb
# Processing Record 0 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 4 | tanki leendert
# City not found. Skipping...
# Processing Record 2 of Set 4 | sabang
# Processing Record 3 of Set 4 | abadan
# Processing Record 4 of Set 4 | kapuskasing
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | kokopo
# Processing Record 7 of Set 4 | gamba
# Processing Record 8 of Set 4 | anadyr
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | altai
# Processing Record 13 of Set 4 | korosten'
# City not found. Skipping...
# Processing Record 14 of Set 4 | ondjiva
# Processing Record 15 of Set 4 | tsumeb
# Processing Record 16 of Set 4 | kenai
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | colonia
# Processing Record 19 of Set 4 | totness
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | alo
# Processing Record 22 of Set 4 | cururupu
# Processing Record 23 of Set 4 | ambar
# Processing Record 24 of Set 4 | new ipswich
# Processing Record 25 of Set 4 | bubaque
# Processing Record 26 of Set 4 | afaahiti
# Processing Record 27 of Set 4 | bredasdorp
# Processing Record 28 of Set 4 | kismayo
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | tezu
# Processing Record 31 of Set 4 | port douglas
# Processing Record 32 of Set 4 | skovorodino
# Processing Record 33 of Set 4 | yuzhno-kurilsk
# Processing Record 34 of Set 4 | wingham
# Processing Record 35 of Set 4 | camarinas
# Processing Record 36 of Set 4 | saipan
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | qal'at bishah
# City not found. Skipping...
# Processing Record 40 of Set 4 | kununurra
# Processing Record 41 of Set 4 | extrema
# Processing Record 42 of Set 4 | chengdu
# Processing Record 43 of Set 4 | nanao
# Processing Record 44 of Set 4 | bairnsdale
# Processing Record 45 of Set 4 | rio pardo de minas
# Processing Record 46 of Set 4 | san antonio de pale
# Processing Record 47 of Set 4 | soio
# Processing Record 48 of Set 4 | suhbaatar
# Processing Record 49 of Set 4 | lalibela
# Processing Record 0 of Set 5 | hammerfest
# Processing Record 1 of Set 5 | stanley
# Processing Record 2 of Set 5 | sao joao da barra
# Processing Record 3 of Set 5 | borgarnes
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 5 | al aaroui
# Processing Record 7 of Set 5 | whitehorse
# Processing Record 8 of Set 5 | quatre cocos
# Processing Record 9 of Set 5 | hatillo
# Processing Record 10 of Set 5 | faya-largeau
# Processing Record 11 of Set 5 | katsuren-haebaru
# Processing Record 12 of Set 5 | la'ie
# Processing Record 13 of Set 5 | ancud
# Processing Record 14 of Set 5 | igarka
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | tateyama
# Processing Record 17 of Set 5 | praya
# Processing Record 18 of Set 5 | aktau
# Processing Record 19 of Set 5 | taulaga
# Processing Record 20 of Set 5 | juneau
# Processing Record 21 of Set 5 | tara
# Processing Record 22 of Set 5 | undurkhaan
# Processing Record 23 of Set 5 | tromso
# Processing Record 24 of Set 5 | byron bay
# Processing Record 25 of Set 5 | palikir - national government center
# Processing Record 26 of Set 5 | hithadhoo
# Processing Record 27 of Set 5 | fort saskatchewan
# Processing Record 28 of Set 5 | north las vegas
# Processing Record 29 of Set 5 | dengzhou
# Processing Record 30 of Set 5 | vorgashor
# Processing Record 31 of Set 5 | timimoun
# Processing Record 32 of Set 5 | amungan
# Processing Record 33 of Set 5 | hadibu
# Processing Record 34 of Set 5 | queenstown
# Processing Record 35 of Set 5 | khanty-mansiysk
# Processing Record 36 of Set 5 | saint croix
# Processing Record 37 of Set 5 | springs
# Processing Record 38 of Set 5 | awjilah
# Processing Record 39 of Set 5 | kristinehamn
# Processing Record 40 of Set 5 | great falls
# Processing Record 41 of Set 5 | pambujan
# Processing Record 42 of Set 5 | sao tome
# Processing Record 43 of Set 5 | alta
# Processing Record 44 of Set 5 | feodosiya
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | souillac
# Processing Record 47 of Set 5 | urengoy
# Processing Record 48 of Set 5 | montepuez
# Processing Record 49 of Set 5 | freeport
# Processing Record 0 of Set 6 | fort bragg
# Processing Record 1 of Set 6 | bonthe
# Processing Record 2 of Set 6 | aral
# Processing Record 3 of Set 6 | sallisaw
# Processing Record 4 of Set 6 | chistopol'
# Processing Record 5 of Set 6 | pangody
# Processing Record 6 of Set 6 | turpan
# Processing Record 7 of Set 6 | pirenopolis
# Processing Record 8 of Set 6 | nevada
# Processing Record 9 of Set 6 | rojhan
# Processing Record 10 of Set 6 | el paujil
# Processing Record 11 of Set 6 | conde
# Processing Record 12 of Set 6 | el granada
# Processing Record 13 of Set 6 | lampang
# Processing Record 14 of Set 6 | kalemie
# Processing Record 15 of Set 6 | ola
# Processing Record 16 of Set 6 | svetlyy
# Processing Record 17 of Set 6 | foumban
# Processing Record 18 of Set 6 | constantia
# Processing Record 19 of Set 6 | mahajanga
# Processing Record 20 of Set 6 | yarmouth
# Processing Record 21 of Set 6 | smithers
# Processing Record 22 of Set 6 | sungai penuh
# Processing Record 23 of Set 6 | payocpoc sur
# Processing Record 24 of Set 6 | konstantinovka
# Processing Record 25 of Set 6 | antsiranana
# Processing Record 26 of Set 6 | apolinario saravia
# Processing Record 27 of Set 6 | doaba
# Processing Record 28 of Set 6 | kwang binh
# Processing Record 29 of Set 6 | anyang
# Processing Record 30 of Set 6 | bhainsdehi
# Processing Record 31 of Set 6 | bahia de kino
# Processing Record 32 of Set 6 | bandundu
# Processing Record 33 of Set 6 | berezovyy
# Processing Record 34 of Set 6 | usinsk
# Processing Record 35 of Set 6 | mossel bay
# Processing Record 36 of Set 6 | turbat
# Processing Record 37 of Set 6 | mount pearl
# Processing Record 38 of Set 6 | kati
# Processing Record 39 of Set 6 | hola
# Processing Record 40 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 6 | taupo
# Processing Record 42 of Set 6 | ponta delgada
# Processing Record 43 of Set 6 | copiapo
# Processing Record 44 of Set 6 | reggane
# Processing Record 45 of Set 6 | salahonda
# Processing Record 46 of Set 6 | chibougamau
# Processing Record 47 of Set 6 | manicore
# Processing Record 48 of Set 6 | wewak
# Processing Record 49 of Set 6 | qarazhal
# Processing Record 0 of Set 7 | qulsary
# Processing Record 1 of Set 7 | touros
# Processing Record 2 of Set 7 | callao
# Processing Record 3 of Set 7 | tangping
# Processing Record 4 of Set 7 | ciutadella
# Processing Record 5 of Set 7 | santa elena de uairen
# Processing Record 6 of Set 7 | zheleznogorsk-ilimskiy
# Processing Record 7 of Set 7 | remire-montjoly
# Processing Record 8 of Set 7 | el bagre
# Processing Record 9 of Set 7 | gotsucho
# Processing Record 10 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 11 of Set 7 | yeppoon
# Processing Record 12 of Set 7 | elliot lake
# Processing Record 13 of Set 7 | hirara
# Processing Record 14 of Set 7 | naha
# Processing Record 15 of Set 7 | singaparna
# Processing Record 16 of Set 7 | norfolk
# Processing Record 17 of Set 7 | nishinoomote
# Processing Record 18 of Set 7 | la passe
# Processing Record 19 of Set 7 | argostolion
# Processing Record 20 of Set 7 | brigantine
# Processing Record 21 of Set 7 | ketchikan
# Processing Record 22 of Set 7 | namibe
# Processing Record 23 of Set 7 | swaffham
# Processing Record 24 of Set 7 | bridgewater
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | teutschenthal
# Processing Record 27 of Set 7 | kamyshlov
# Processing Record 28 of Set 7 | sirte
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | ciudad guayana
# Processing Record 31 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 32 of Set 7 | petra
# Processing Record 33 of Set 7 | madimba
# Processing Record 34 of Set 7 | tocopilla
# Processing Record 35 of Set 7 | susuman
# Processing Record 36 of Set 7 | punta arenas
# Processing Record 37 of Set 7 | kalmunai
# Processing Record 38 of Set 7 | kaiapoi
# Processing Record 39 of Set 7 | aasiaat
# Processing Record 40 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 7 | mangalia
# Processing Record 42 of Set 7 | arno
# Processing Record 43 of Set 7 | mar del plata
# Processing Record 44 of Set 7 | quang ngai
# Processing Record 45 of Set 7 | the pinery
# Processing Record 46 of Set 7 | novodvinsk
# Processing Record 47 of Set 7 | florence
# Processing Record 48 of Set 7 | baqubah
# Processing Record 49 of Set 7 | masterton
# Processing Record 0 of Set 8 | yebaishou
# Processing Record 1 of Set 8 | dunedin
# Processing Record 2 of Set 8 | rodino
# Processing Record 3 of Set 8 | nyurba
# Processing Record 4 of Set 8 | bolkhov
# Processing Record 5 of Set 8 | lukolela
# Processing Record 6 of Set 8 | gisborne
# Processing Record 7 of Set 8 | mihaesti
# Processing Record 8 of Set 8 | st. john's
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | el tigre
# Processing Record 11 of Set 8 | tullins
# Processing Record 12 of Set 8 | new norfolk
# Processing Record 13 of Set 8 | coahuayana de hidalgo
# Processing Record 14 of Set 8 | puerto baquerizo moreno
# Processing Record 15 of Set 8 | keflavik
# Processing Record 16 of Set 8 | turkmenbasy
# Processing Record 17 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 18 of Set 8 | puerto aysen
# Processing Record 19 of Set 8 | at taj
# Processing Record 20 of Set 8 | tshabong
# Processing Record 21 of Set 8 | juan griego
# Processing Record 22 of Set 8 | iskateley
# Processing Record 23 of Set 8 | coquimbo
# Processing Record 24 of Set 8 | geraldton
# Processing Record 25 of Set 8 | tura
# Processing Record 26 of Set 8 | kencong
# Processing Record 27 of Set 8 | leava
# Processing Record 28 of Set 8 | nouadhibou
# Processing Record 29 of Set 8 | tadine
# Processing Record 30 of Set 8 | rio casca
# Processing Record 31 of Set 8 | saint-louis
# Processing Record 32 of Set 8 | cajazeiras
# Processing Record 33 of Set 8 | weno
# Processing Record 34 of Set 8 | valparaiso
# Processing Record 35 of Set 8 | tofol
# Processing Record 36 of Set 8 | haciqabul
# Processing Record 37 of Set 8 | debark'
# Processing Record 38 of Set 8 | ulaangom
# Processing Record 39 of Set 8 | lichtenburg
# Processing Record 40 of Set 8 | cadale
# Processing Record 41 of Set 8 | snihurivka
# Processing Record 42 of Set 8 | gyeongsan-si
# Processing Record 43 of Set 8 | merizo village
# Processing Record 44 of Set 8 | fisterra
# Processing Record 45 of Set 8 | powell river
# Processing Record 46 of Set 8 | heihe
# Processing Record 47 of Set 8 | azul
# Processing Record 48 of Set 8 | kaspiyskiy
# Processing Record 49 of Set 8 | koneurgench
# City not found. Skipping...
# Processing Record 0 of Set 9 | thunder bay
# Processing Record 1 of Set 9 | placido de castro
# Processing Record 2 of Set 9 | tazovsky
# Processing Record 3 of Set 9 | zhezqazghan
# Processing Record 4 of Set 9 | kyzyl-mazhalyk
# Processing Record 5 of Set 9 | lewistown
# Processing Record 6 of Set 9 | steamboat springs
# Processing Record 7 of Set 9 | nizhniy odes
# Processing Record 8 of Set 9 | fukuecho
# Processing Record 9 of Set 9 | mugia
# Processing Record 10 of Set 9 | castres
# Processing Record 11 of Set 9 | my tho
# Processing Record 12 of Set 9 | sidi okba
# Processing Record 13 of Set 9 | murehwa
# Processing Record 14 of Set 9 | barcelos
# Processing Record 15 of Set 9 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 16 of Set 9 | porto novo
# Processing Record 17 of Set 9 | marka
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | dawei
# Processing Record 20 of Set 9 | yambio
# Processing Record 21 of Set 9 | mildura
# Processing Record 22 of Set 9 | barmer
# Processing Record 23 of Set 9 | port blair
# Processing Record 24 of Set 9 | tejen
# Processing Record 25 of Set 9 | hobyo
# Processing Record 26 of Set 9 | preobrazheniye
# Processing Record 27 of Set 9 | kibungo
# Processing Record 28 of Set 9 | tanaina
# Processing Record 29 of Set 9 | sumenep
# Processing Record 30 of Set 9 | mira mesa
# Processing Record 31 of Set 9 | galle
# Processing Record 32 of Set 9 | chelghoum el aid
# Processing Record 33 of Set 9 | shar'ya
# Processing Record 34 of Set 9 | bardai
# Processing Record 35 of Set 9 | rakops
# Processing Record 36 of Set 9 | suva
# Processing Record 37 of Set 9 | sibay
# Processing Record 38 of Set 9 | helsinki
# Processing Record 39 of Set 9 | pisco
# Processing Record 40 of Set 9 | choibalsan
# Processing Record 41 of Set 9 | kaa-khem
# Processing Record 42 of Set 9 | livny
# Processing Record 43 of Set 9 | saint-joseph
# Processing Record 44 of Set 9 | nar'yan-mar
# Processing Record 45 of Set 9 | zaozersk
# Processing Record 46 of Set 9 | sawai madhopur
# Processing Record 47 of Set 9 | henryetta
# Processing Record 48 of Set 9 | mersa matruh
# Processing Record 49 of Set 9 | begun
# Processing Record 0 of Set 10 | cidade velha
# Processing Record 1 of Set 10 | pumiao
# Processing Record 2 of Set 10 | murzuq
# Processing Record 3 of Set 10 | portland
# Processing Record 4 of Set 10 | harstad
# Processing Record 5 of Set 10 | trincomalee
# Processing Record 6 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 10 | moapa valley
# Processing Record 8 of Set 10 | santa cruz
# Processing Record 9 of Set 10 | golyshmanovo
# Processing Record 10 of Set 10 | tosontsengel
# Processing Record 11 of Set 10 | timbuktu
# Processing Record 12 of Set 10 | mount isa
# Processing Record 13 of Set 10 | karatas
# Processing Record 14 of Set 10 | jiayuguan
# Processing Record 15 of Set 10 | puerto leguizamo
# Processing Record 16 of Set 10 | laramie
# Processing Record 17 of Set 10 | jieshi
# Processing Record 18 of Set 10 | nova vicosa
# Processing Record 19 of Set 10 | pointe-noire
# Processing Record 20 of Set 10 | puerto real
# Processing Record 21 of Set 10 | zhanaozen
# Processing Record 22 of Set 10 | nova sintra
# Processing Record 23 of Set 10 | arteche
# Processing Record 24 of Set 10 | bani walid
# Processing Record 25 of Set 10 | valdivia
# Processing Record 26 of Set 10 | bengkulu
# Processing Record 27 of Set 10 | emerald
# Processing Record 28 of Set 10 | chardara
# Processing Record 29 of Set 10 | chokwe
# Processing Record 30 of Set 10 | urangan
# Processing Record 31 of Set 10 | burang
# Processing Record 32 of Set 10 | rome
# Processing Record 33 of Set 10 | port isabel
# Processing Record 34 of Set 10 | isle of lewis
# City not found. Skipping...
# Processing Record 35 of Set 10 | ceerigaabo
# Processing Record 36 of Set 10 | avanigadda
# Processing Record 37 of Set 10 | freetown
# Processing Record 38 of Set 10 | caconda
# Processing Record 39 of Set 10 | campbell river
# Processing Record 40 of Set 10 | chebarkul'
# Processing Record 41 of Set 10 | north lakhimpur
# Processing Record 42 of Set 10 | kish
# Processing Record 43 of Set 10 | mejit
# Processing Record 44 of Set 10 | betio village
# Processing Record 45 of Set 10 | sumberpucung
# Processing Record 46 of Set 10 | hotan
# Processing Record 47 of Set 10 | wynyard
# Processing Record 48 of Set 10 | mahanoro
# Processing Record 49 of Set 10 | ihosy
# Processing Record 0 of Set 11 | pingxiang
# Processing Record 1 of Set 11 | okhotsk
# Processing Record 2 of Set 11 | sao felix do xingu
# Processing Record 3 of Set 11 | sao pedro do sul
# Processing Record 4 of Set 11 | vorkuta
# Processing Record 5 of Set 11 | launceston
# Processing Record 6 of Set 11 | new plymouth
# Processing Record 7 of Set 11 | port-vila
# Processing Record 8 of Set 11 | selfoss
# Processing Record 9 of Set 11 | cannonvale
# Processing Record 10 of Set 11 | pervari
# Processing Record 11 of Set 11 | flying fish cove
# Processing Record 12 of Set 11 | tralee
# Processing Record 13 of Set 11 | banda aceh
# Processing Record 14 of Set 11 | diamantino
# Processing Record 15 of Set 11 | quetigny
# Processing Record 16 of Set 11 | kapa'a
# Processing Record 17 of Set 11 | inarajan village
# Processing Record 18 of Set 11 | puerto deseado
# Processing Record 19 of Set 11 | kone
# Processing Record 20 of Set 11 | vilyuchinsk
# Processing Record 21 of Set 11 | le port
# Processing Record 22 of Set 11 | san juan de la rambla
# Processing Record 23 of Set 11 | lensk
# Processing Record 24 of Set 11 | hasaki
# Processing Record 25 of Set 11 | tommot
# Processing Record 26 of Set 11 | turbo
# Processing Record 27 of Set 11 | oranjemund
# Processing Record 28 of Set 11 | penzance
# Processing Record 29 of Set 11 | kogalym
# Processing Record 30 of Set 11 | xiaoshi
# Processing Record 31 of Set 11 | valjevo
# Processing Record 32 of Set 11 | yendi
# Processing Record 33 of Set 11 | vavuniya
# Processing Record 34 of Set 11 | zhongshu
# Processing Record 35 of Set 11 | xai-xai
# Processing Record 36 of Set 11 | mbekenyera
# Processing Record 37 of Set 11 | el matama
# Processing Record 38 of Set 11 | tangalle
# Processing Record 39 of Set 11 | ghat
# Processing Record 40 of Set 11 | giyani
# Processing Record 41 of Set 11 | tazacorte
# Processing Record 42 of Set 11 | kirensk
# Processing Record 43 of Set 11 | melekeok village
# Processing Record 44 of Set 11 | ta`u
# Processing Record 45 of Set 11 | stephenville
# Processing Record 46 of Set 11 | island harbour
# Processing Record 47 of Set 11 | orchard homes
# Processing Record 48 of Set 11 | agat village
# Processing Record 49 of Set 11 | north bay
# Processing Record 0 of Set 12 | lamu
# Processing Record 1 of Set 12 | san carlos
# Processing Record 2 of Set 12 | guerrero negro
# Processing Record 3 of Set 12 | gadzhiyevo
# Processing Record 4 of Set 12 | vila velha
# Processing Record 5 of Set 12 | nadi
# Processing Record 6 of Set 12 | narrabri
# Processing Record 7 of Set 12 | forster
# Processing Record 8 of Set 12 | bismarck
# Processing Record 9 of Set 12 | yeniseysk
# Processing Record 10 of Set 12 | ar rutbah
# Processing Record 11 of Set 12 | balcarce
# Processing Record 12 of Set 12 | prineville
# Processing Record 13 of Set 12 | delta
# Processing Record 14 of Set 12 | wurtulla
# Processing Record 15 of Set 12 | darnah
# Processing Record 16 of Set 12 | san fernando
# Processing Record 17 of Set 12 | nantucket
# Processing Record 18 of Set 12 | kristiansund
# Processing Record 19 of Set 12 | nuuk
# Processing Record 20 of Set 12 | port augusta
# Processing Record 21 of Set 12 | inhambane
# Processing Record 22 of Set 12 | celestun
# Processing Record 23 of Set 12 | namtsy
# Processing Record 24 of Set 12 | axim
# Processing Record 25 of Set 12 | emiliano zapata
# Processing Record 26 of Set 12 | papao
# Processing Record 27 of Set 12 | necochea
# Processing Record 28 of Set 12 | chegdomyn
# Processing Record 29 of Set 12 | chui
# Processing Record 30 of Set 12 | happy valley-goose bay
# Processing Record 31 of Set 12 | tsiombe
# Processing Record 32 of Set 12 | petawawa
# Processing Record 33 of Set 12 | rio grande
# Processing Record 34 of Set 12 | puerto asis
# Processing Record 35 of Set 12 | winneba
# Processing Record 36 of Set 12 | arapgir
# Processing Record 37 of Set 12 | cruzeiro do sul
# Processing Record 38 of Set 12 | baoqing
# Processing Record 39 of Set 12 | cooma
# Processing Record 40 of Set 12 | howrah
# Processing Record 41 of Set 12 | yelizovo
# Processing Record 42 of Set 12 | trostyanets'
# Processing Record 43 of Set 12 | mitu
# Processing Record 44 of Set 12 | devinuwara
# City not found. Skipping...
# Processing Record 45 of Set 12 | lepsy
# Processing Record 46 of Set 12 | revda
# Processing Record 47 of Set 12 | acworth
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          ugoofaaru   5.6667   73.0000     28.24        77         100
# 1             mhamid  29.8200   -5.7200     30.11        18           0
# 2             bethel  41.3712  -73.4140     21.31        68          20
# 3           enewetak  11.3474  162.3373     27.83        77          98
# 4  wailua homesteads  22.0669 -159.3780     28.24        76          40
#
#    Wind Speed Country        Date
# 0        6.78      MV  1687388752
# 1        5.36      MA  1687388752
# 2        3.09      US  1687388631
# 3        7.07      MH  1687388752
# 4        5.66      US  1687388752

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data\cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ugoofaaru   5.6667   73.0000     28.24        77         100
# 1                   mhamid  29.8200   -5.7200     30.11        18           0
# 2                   bethel  41.3712  -73.4140     21.31        68          20
# 3                 enewetak  11.3474  162.3373     27.83        77          98
# 4        wailua homesteads  22.0669 -159.3780     28.24        76          40
#
#          Wind Speed Country        Date
# City_ID
# 0              6.78      MV  1687388752
# 1              5.36      MA  1687388752
# 2              3.09      US  1687388631
# 3              7.07      MH  1687388752
# 4              5.66      US  1687388752

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x="Lat",y="Max Temp",grid=True,edgecolors='black')
today = date.today()
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title (f"City Max Temperature vs. Latitude({today})")
plt.ylim(-20,40)
plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x="Lat", y="Humidity", grid=True,edgecolors='black')
today = date.today()
# Incorporate the other graph properties
plt.xlabel("Latitude")# YOUR CODE HERE
plt.ylabel("Humidity(%)")
plt.title(f"City Latititude vs. Humidity({today})")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x="Lat", y="Cloudiness", grid=True,edgecolors='black')
# Incorporate the other graph properties
plt.xlabel("Latitude")# YOUR CODE HERE
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latititude vs. Cloudiness({today})")
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x="Lat", y="Wind Speed", grid=True,edgecolors='black')
# Incorporate the other graph properties
plt.xlabel("Latitude")# YOUR CODE HERE
plt.ylabel("Wind Speed(m/s)")
plt.title(f"City Latititude vs. Wind Speed({today})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def my_function(x,y):
    (slope, intercept, r, p, se) = linregress(x,y)
    return x
    res = x * slope + intercept
    line_eq="y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ugoofaaru   5.6667   73.0000     28.24        77         100
# 1                   mhamid  29.8200   -5.7200     30.11        18           0
# 2                   bethel  41.3712  -73.4140     21.31        68          20
# 3                 enewetak  11.3474  162.3373     27.83        77          98
# 4        wailua homesteads  22.0669 -159.3780     28.24        76          40
#
#          Wind Speed Country        Date
# City_ID
# 0              6.78      MV  1687388752
# 1              5.36      MA  1687388752
# 2              3.09      US  1687388631
# 3              7.07      MH  1687388752
# 4              5.66      US  1687388752

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5            grytviken -54.2811  -36.5092      0.03        83          60
# 6            adamstown -25.0660 -130.1015     22.47        91          75
# 7             jayapura  -2.5333  140.7000     25.66        90         100
# 12            waitangi -43.9535 -176.5597     12.68        76          25
# 13       port mathurin -19.6833   63.4167     23.74        59          25
#
#          Wind Speed Country        Date
# City_ID
# 5              2.73      GS  1687388753
# 6             10.00      PN  1687388753
# 7              1.80      ID  1687388753
# 12             4.47      NZ  1687388754
# 13             8.91      MU  1687388484

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
my_function(northern_hemi_df["Max Temp"],northern_hemi_df['Lat'])
print(res)
# Out:
# None

# %%
# Linear regression on Northern Hemisphere
northern_hemi_df.plot.scatter("Lat", "Max Temp", edgecolors="black",grid=True)
my_function(northern_hemi_df['Lat'],northern_hemi_df["Max Temp"])
plt.plot(northern_hemi_df["Lat"],res,'r-')
plt.annotate(line_eq,( 5,10),fontsize=15, color='red')
plt.tight_layout()
# YOUR CODE HERE
plt.show()
print(r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 4
#       2 northern_hemi_df.plot.scatter("Lat", "Max Temp", edgecolors="black",grid=True)
#       3 my_function(northern_hemi_df['Lat'],northern_hemi_df["Max Temp"])
# ----> 4 plt.plot(northern_hemi_df["Lat"],res,'r-')
#       5 plt.annotate(line_eq,( 5,10),fontsize=15, color='red')
#       6 plt.tight_layout()
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File C:\ProgramData\anaconda3\lib\site-packages\matplotlib\axes\_base.py:465, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     462 # Don't allow any None value; these would be up-converted to one
#     463 # element array of None which causes problems downstream.
#     464 if any(v is None for v in tup):
# --> 465     raise ValueError("x, y, and format string must not be None")
#     467 kw = {}
#     468 for prop_name, val in zip(('linestyle', 'marker', 'color'),
#     469                           (linestyle, marker, color)):
#
# ValueError: x, y, and format string must not be None

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
