# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}" # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}&units=metric" # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"] # YOUR CODE HERE
        city_lng = city_weather["coord"]["lon"]# YOUR CODE HERE
        city_max_temp = city_weather['main']['temp_max'] # YOUR CODE HERE
        city_humidity = city_weather['main']['humidity']# YOUR CODE HERE
        city_clouds = city_weather['clouds']['all']# YOUR CODE HERE
        city_wind = city_weather['wind']['speed']# YOUR CODE HERE
        city_country = city_weather["sys"]['country'] # YOUR CODE HERE
        city_date = city_weather['dt']# YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | uturoa
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | keflavik
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | deutschlandsberg
# Processing Record 7 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 8 of Set 1 | labuan lombok
# City not found. Skipping...
# Processing Record 9 of Set 1 | susuman
# Processing Record 10 of Set 1 | puerto natales
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | mokhsogollokh
# Processing Record 13 of Set 1 | margaret river
# Processing Record 14 of Set 1 | ipora
# Processing Record 15 of Set 1 | tono
# Processing Record 16 of Set 1 | edinburgh of the seven seas
# Processing Record 17 of Set 1 | panacan
# Processing Record 18 of Set 1 | blackmans bay
# Processing Record 19 of Set 1 | hamilton
# Processing Record 20 of Set 1 | iskateley
# Processing Record 21 of Set 1 | fort wellington
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | whitehorse
# Processing Record 24 of Set 1 | antalaha
# Processing Record 25 of Set 1 | bilibino
# Processing Record 26 of Set 1 | lihue
# Processing Record 27 of Set 1 | palangkaraya
# Processing Record 28 of Set 1 | nowa sarzyna
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | nampula
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | kiunga
# Processing Record 33 of Set 1 | la sarre
# Processing Record 34 of Set 1 | fale old settlement
# Processing Record 35 of Set 1 | sampit
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | tarawa
# Processing Record 38 of Set 1 | flying fish cove
# Processing Record 39 of Set 1 | grants pass
# Processing Record 40 of Set 1 | karungdong
# Processing Record 41 of Set 1 | kurchum
# Processing Record 42 of Set 1 | arroyo
# Processing Record 43 of Set 1 | erenhot
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | port mathurin
# Processing Record 46 of Set 1 | aykol
# City not found. Skipping...
# Processing Record 47 of Set 1 | port-aux-francais
# Processing Record 48 of Set 1 | utrik
# Processing Record 49 of Set 1 | olyokminsk
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | ilulissat
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | okahao
# Processing Record 3 of Set 2 | lompoc
# Processing Record 4 of Set 2 | yondo
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | villa tecolutilla
# Processing Record 7 of Set 2 | qaqortoq
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | goure
# Processing Record 10 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 11 of Set 2 | hawaiian paradise park
# Processing Record 12 of Set 2 | wailua homesteads
# Processing Record 13 of Set 2 | kerikeri
# Processing Record 14 of Set 2 | chernyshevsk
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | dongola
# Processing Record 18 of Set 2 | magomeni
# Processing Record 19 of Set 2 | cill airne
# Processing Record 20 of Set 2 | papatowai
# Processing Record 21 of Set 2 | invercargill
# Processing Record 22 of Set 2 | tamiahua
# Processing Record 23 of Set 2 | nebraska city
# Processing Record 24 of Set 2 | fonte boa
# Processing Record 25 of Set 2 | aitape
# Processing Record 26 of Set 2 | rabak
# Processing Record 27 of Set 2 | boende
# Processing Record 28 of Set 2 | taro
# Processing Record 29 of Set 2 | sosnovo-ozerskoye
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | sandnessjoen
# Processing Record 32 of Set 2 | badger
# Processing Record 33 of Set 2 | pakuranga
# Processing Record 34 of Set 2 | afaahiti
# Processing Record 35 of Set 2 | bafoulabe
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | gokwe
# Processing Record 38 of Set 2 | kodiak
# Processing Record 39 of Set 2 | cannonvale
# Processing Record 40 of Set 2 | rawson
# Processing Record 41 of Set 2 | tulum
# Processing Record 42 of Set 2 | vernon
# Processing Record 43 of Set 2 | urangan
# Processing Record 44 of Set 2 | stanley
# Processing Record 45 of Set 2 | isafjordur
# Processing Record 46 of Set 2 | bandundu
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | vorgashor
# Processing Record 49 of Set 2 | nantucket
# Processing Record 0 of Set 3 | sabang
# Processing Record 1 of Set 3 | sabha
# Processing Record 2 of Set 3 | dudinka
# Processing Record 3 of Set 3 | deqen
# Processing Record 4 of Set 3 | molteno
# Processing Record 5 of Set 3 | alto araguaia
# Processing Record 6 of Set 3 | floro
# Processing Record 7 of Set 3 | constantia
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | puerto baquerizo moreno
# Processing Record 11 of Set 3 | weno
# Processing Record 12 of Set 3 | sofiyivka
# Processing Record 13 of Set 3 | nemuro
# Processing Record 14 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 15 of Set 3 | talakan
# Processing Record 16 of Set 3 | nashtarud
# City not found. Skipping...
# Processing Record 17 of Set 3 | bandon
# Processing Record 18 of Set 3 | civitavecchia
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | yuzhno-kurilsk
# Processing Record 21 of Set 3 | udachny
# Processing Record 22 of Set 3 | pont rouge
# Processing Record 23 of Set 3 | toliara
# Processing Record 24 of Set 3 | wewak
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | urrao
# Processing Record 27 of Set 3 | hammerfest
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | st. john's
# Processing Record 30 of Set 3 | dan gora
# Processing Record 31 of Set 3 | piton saint-leu
# Processing Record 32 of Set 3 | west island
# Processing Record 33 of Set 3 | ust-nera
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | klyuchi
# Processing Record 36 of Set 3 | al marj
# Processing Record 37 of Set 3 | anloga
# Processing Record 38 of Set 3 | mananjary
# Processing Record 39 of Set 3 | letlhakeng
# Processing Record 40 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 3 | brevik
# Processing Record 42 of Set 3 | saipan
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | nishinoomote
# Processing Record 45 of Set 3 | istra
# Processing Record 46 of Set 3 | ta`u
# Processing Record 47 of Set 3 | callao
# Processing Record 48 of Set 3 | albany
# Processing Record 49 of Set 3 | beloyarskiy
# Processing Record 0 of Set 4 | talnakh
# Processing Record 1 of Set 4 | chonchi
# Processing Record 2 of Set 4 | xining
# Processing Record 3 of Set 4 | kapuskasing
# Processing Record 4 of Set 4 | ishimbay
# Processing Record 5 of Set 4 | posse
# Processing Record 6 of Set 4 | taulaga
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | la passe
# Processing Record 9 of Set 4 | pirapora
# Processing Record 10 of Set 4 | key west
# Processing Record 11 of Set 4 | magadan
# Processing Record 12 of Set 4 | williams lake
# Processing Record 13 of Set 4 | enewetak
# Processing Record 14 of Set 4 | olonkinbyen
# Processing Record 15 of Set 4 | mangrol
# Processing Record 16 of Set 4 | mwandiga
# Processing Record 17 of Set 4 | okha
# Processing Record 18 of Set 4 | elmendorf air force base
# City not found. Skipping...
# Processing Record 19 of Set 4 | alice springs
# Processing Record 20 of Set 4 | fort bragg
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | tralee
# Processing Record 23 of Set 4 | gamba
# Processing Record 24 of Set 4 | jamestown
# Processing Record 25 of Set 4 | aripuana
# Processing Record 26 of Set 4 | bloemfontein
# Processing Record 27 of Set 4 | pingliang
# Processing Record 28 of Set 4 | ambon
# Processing Record 29 of Set 4 | hami
# Processing Record 30 of Set 4 | nacala
# Processing Record 31 of Set 4 | san rafael del sur
# Processing Record 32 of Set 4 | maloye ganyushkino
# Processing Record 33 of Set 4 | kasongo-lunda
# Processing Record 34 of Set 4 | hirara
# Processing Record 35 of Set 4 | hetauda
# Processing Record 36 of Set 4 | mount isa
# Processing Record 37 of Set 4 | koubia
# Processing Record 38 of Set 4 | birjand
# Processing Record 39 of Set 4 | college
# Processing Record 40 of Set 4 | vadso
# Processing Record 41 of Set 4 | fada
# Processing Record 42 of Set 4 | sinabang
# Processing Record 43 of Set 4 | sur
# Processing Record 44 of Set 4 | lebu
# Processing Record 45 of Set 4 | douglas
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | grants
# Processing Record 48 of Set 4 | suwannaphum
# Processing Record 49 of Set 4 | kodinsk
# Processing Record 0 of Set 5 | ciudad lazaro cardenas
# Processing Record 1 of Set 5 | sao gabriel da cachoeira
# Processing Record 2 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | inderbor
# Processing Record 5 of Set 5 | dzhangala
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | merizo village
# Processing Record 8 of Set 5 | neryungri
# Processing Record 9 of Set 5 | dongtai
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | papao
# Processing Record 12 of Set 5 | malpe
# Processing Record 13 of Set 5 | dzhalagash
# Processing Record 14 of Set 5 | vorkuta
# Processing Record 15 of Set 5 | pando
# Processing Record 16 of Set 5 | santa elena de uairen
# Processing Record 17 of Set 5 | waddan
# Processing Record 18 of Set 5 | keuruu
# Processing Record 19 of Set 5 | pangody
# Processing Record 20 of Set 5 | turkmenbasy
# Processing Record 21 of Set 5 | dakhla
# Processing Record 22 of Set 5 | gladstone
# Processing Record 23 of Set 5 | metu
# Processing Record 24 of Set 5 | paita
# Processing Record 25 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 5 | rouissat
# Processing Record 27 of Set 5 | suihua
# Processing Record 28 of Set 5 | morrilton
# Processing Record 29 of Set 5 | tahe
# Processing Record 30 of Set 5 | nahiyat ash shinafiyah
# Processing Record 31 of Set 5 | indre arna
# Processing Record 32 of Set 5 | palikir - national government center
# Processing Record 33 of Set 5 | agat village
# Processing Record 34 of Set 5 | carnarvon
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | jiuquan
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | pekanbaru
# Processing Record 39 of Set 5 | kone
# Processing Record 40 of Set 5 | masterton
# Processing Record 41 of Set 5 | kailua-kona
# Processing Record 42 of Set 5 | nar'yan-mar
# Processing Record 43 of Set 5 | lerwick
# Processing Record 44 of Set 5 | khandyga
# Processing Record 45 of Set 5 | seeb
# Processing Record 46 of Set 5 | thunder bay
# Processing Record 47 of Set 5 | natal
# Processing Record 48 of Set 5 | haiku-pauwela
# Processing Record 49 of Set 5 | aasiaat
# Processing Record 0 of Set 6 | quellon
# Processing Record 1 of Set 6 | hermanus
# Processing Record 2 of Set 6 | ust-tsilma
# Processing Record 3 of Set 6 | hafar al-batin
# Processing Record 4 of Set 6 | santo antonio do ica
# Processing Record 5 of Set 6 | suva
# Processing Record 6 of Set 6 | tukrah
# Processing Record 7 of Set 6 | kuching
# Processing Record 8 of Set 6 | avarua
# Processing Record 9 of Set 6 | janauba
# Processing Record 10 of Set 6 | acajutla
# Processing Record 11 of Set 6 | chibougamau
# Processing Record 12 of Set 6 | ouadda
# Processing Record 13 of Set 6 | atafu village
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | aragarcas
# Processing Record 16 of Set 6 | port macquarie
# Processing Record 17 of Set 6 | alexandria
# Processing Record 18 of Set 6 | zeya
# Processing Record 19 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 20 of Set 6 | chiredzi
# Processing Record 21 of Set 6 | ola
# Processing Record 22 of Set 6 | mlalo
# Processing Record 23 of Set 6 | namibe
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | markala
# Processing Record 26 of Set 6 | san antonio de pale
# Processing Record 27 of Set 6 | salsomaggiore terme
# Processing Record 28 of Set 6 | lashio
# Processing Record 29 of Set 6 | okhotsk
# Processing Record 30 of Set 6 | antigua
# Processing Record 31 of Set 6 | san luis
# Processing Record 32 of Set 6 | hadibu
# Processing Record 33 of Set 6 | novyy urengoy
# Processing Record 34 of Set 6 | vilyuchinsk
# Processing Record 35 of Set 6 | awjilah
# Processing Record 36 of Set 6 | tuy hoa
# Processing Record 37 of Set 6 | padam
# City not found. Skipping...
# Processing Record 38 of Set 6 | igarka
# Processing Record 39 of Set 6 | maros
# City not found. Skipping...
# Processing Record 40 of Set 6 | buka
# Processing Record 41 of Set 6 | santa cruz
# Processing Record 42 of Set 6 | kyabe
# Processing Record 43 of Set 6 | tosontsengel
# Processing Record 44 of Set 6 | riberalta
# Processing Record 45 of Set 6 | loudeac
# Processing Record 46 of Set 6 | alo
# Processing Record 47 of Set 6 | nha trang
# Processing Record 48 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 6 | maumere
# Processing Record 0 of Set 7 | hemsby
# Processing Record 1 of Set 7 | jayapura
# Processing Record 2 of Set 7 | dryden
# City not found. Skipping...
# Processing Record 3 of Set 7 | wajir
# City not found. Skipping...
# Processing Record 4 of Set 7 | juankoski
# Processing Record 5 of Set 7 | rikaze
# Processing Record 6 of Set 7 | road town
# Processing Record 7 of Set 7 | zhangjiakou
# Processing Record 8 of Set 7 | hithadhoo
# Processing Record 9 of Set 7 | tolanaro
# Processing Record 10 of Set 7 | tazacorte
# Processing Record 11 of Set 7 | arraias
# Processing Record 12 of Set 7 | ocean pointe
# City not found. Skipping...
# Processing Record 13 of Set 7 | selfoss
# Processing Record 14 of Set 7 | simpang
# Processing Record 15 of Set 7 | hit
# Processing Record 16 of Set 7 | morehead city
# Processing Record 17 of Set 7 | fallon
# Processing Record 18 of Set 7 | mount gambier
# Processing Record 19 of Set 7 | rosarito
# Processing Record 20 of Set 7 | isle of lewis
# City not found. Skipping...
# Processing Record 21 of Set 7 | xinyuan
# Processing Record 22 of Set 7 | yelizovo
# Processing Record 23 of Set 7 | ebon
# Processing Record 24 of Set 7 | port blair
# Processing Record 25 of Set 7 | kisanga
# Processing Record 26 of Set 7 | pervomayskoye
# Processing Record 27 of Set 7 | barcelos
# Processing Record 28 of Set 7 | marsala
# Processing Record 29 of Set 7 | mbandaka
# Processing Record 30 of Set 7 | najaf
# Processing Record 31 of Set 7 | dahab
# Processing Record 32 of Set 7 | nuuk
# Processing Record 33 of Set 7 | macia
# Processing Record 34 of Set 7 | pokrovsk
# Processing Record 35 of Set 7 | antsiranana
# Processing Record 36 of Set 7 | cabo san lucas
# Processing Record 37 of Set 7 | broken hill
# Processing Record 38 of Set 7 | mweka
# Processing Record 39 of Set 7 | ankang
# Processing Record 40 of Set 7 | vila franca do campo
# Processing Record 41 of Set 7 | najran
# Processing Record 42 of Set 7 | kourou
# Processing Record 43 of Set 7 | juan griego
# Processing Record 44 of Set 7 | petauke
# Processing Record 45 of Set 7 | umm kaddadah
# Processing Record 46 of Set 7 | newport
# Processing Record 47 of Set 7 | dunedin
# Processing Record 48 of Set 7 | mahanoro
# Processing Record 49 of Set 7 | gadzhiyevo
# Processing Record 0 of Set 8 | margate
# Processing Record 1 of Set 8 | batouri
# Processing Record 2 of Set 8 | tianpeng
# Processing Record 3 of Set 8 | ribeira brava
# Processing Record 4 of Set 8 | napanee
# Processing Record 5 of Set 8 | gurupa
# Processing Record 6 of Set 8 | roxas
# Processing Record 7 of Set 8 | mhamid
# Processing Record 8 of Set 8 | khanjarah
# Processing Record 9 of Set 8 | puente nacional
# Processing Record 10 of Set 8 | xai-xai
# Processing Record 11 of Set 8 | tsiombe
# Processing Record 12 of Set 8 | general mosconi
# Processing Record 13 of Set 8 | sakassou
# Processing Record 14 of Set 8 | mana
# Processing Record 15 of Set 8 | santyoku
# Processing Record 16 of Set 8 | north shore
# Processing Record 17 of Set 8 | bakanas
# Processing Record 18 of Set 8 | happy valley-goose bay
# Processing Record 19 of Set 8 | vega de alatorre
# Processing Record 20 of Set 8 | page
# Processing Record 21 of Set 8 | itaituba
# Processing Record 22 of Set 8 | nouadhibou
# Processing Record 23 of Set 8 | saint-denis
# Processing Record 24 of Set 8 | island harbour
# Processing Record 25 of Set 8 | port alfred
# Processing Record 26 of Set 8 | tanggu
# Processing Record 27 of Set 8 | dzuunharaa
# Processing Record 28 of Set 8 | rio grande city
# Processing Record 29 of Set 8 | bandipura
# Processing Record 30 of Set 8 | alaghsas
# Processing Record 31 of Set 8 | orosei
# Processing Record 32 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 8 | flin flon
# Processing Record 34 of Set 8 | kapoeta
# Processing Record 35 of Set 8 | camaiore
# Processing Record 36 of Set 8 | missoula
# Processing Record 37 of Set 8 | kegen
# Processing Record 38 of Set 8 | khilchipur
# Processing Record 39 of Set 8 | manokwari
# Processing Record 40 of Set 8 | malvan
# Processing Record 41 of Set 8 | blagoveshchenka
# Processing Record 42 of Set 8 | corner brook
# Processing Record 43 of Set 8 | nuku'alofa
# Processing Record 44 of Set 8 | bowling green
# Processing Record 45 of Set 8 | swakopmund
# Processing Record 46 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 8 | edson
# Processing Record 48 of Set 8 | sao vicente
# Processing Record 49 of Set 8 | caleta de carquin
# Processing Record 0 of Set 9 | okola
# Processing Record 1 of Set 9 | bodaybo
# Processing Record 2 of Set 9 | greenville
# Processing Record 3 of Set 9 | zahedan
# Processing Record 4 of Set 9 | saynshand
# Processing Record 5 of Set 9 | tabuk
# Processing Record 6 of Set 9 | lamar
# Processing Record 7 of Set 9 | severo-yeniseyskiy
# Processing Record 8 of Set 9 | namdrik
# Processing Record 9 of Set 9 | maintirano
# Processing Record 10 of Set 9 | port augusta
# Processing Record 11 of Set 9 | turuntayevo
# Processing Record 12 of Set 9 | punta del este
# Processing Record 13 of Set 9 | kosan
# Processing Record 14 of Set 9 | labasa
# Processing Record 15 of Set 9 | port victoria
# Processing Record 16 of Set 9 | sainte-anne-des-monts
# Processing Record 17 of Set 9 | novi ligure
# Processing Record 18 of Set 9 | mukalla
# Processing Record 19 of Set 9 | belyy yar
# Processing Record 20 of Set 9 | shetpe
# Processing Record 21 of Set 9 | kenora
# Processing Record 22 of Set 9 | nova sintra
# Processing Record 23 of Set 9 | ceerigaabo
# Processing Record 24 of Set 9 | harper
# Processing Record 25 of Set 9 | saint-joseph
# Processing Record 26 of Set 9 | tura
# Processing Record 27 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 28 of Set 9 | al jawf
# Processing Record 29 of Set 9 | hassi messaoud
# Processing Record 30 of Set 9 | gaigeturi
# Processing Record 31 of Set 9 | rio gallegos
# Processing Record 32 of Set 9 | port isabel
# Processing Record 33 of Set 9 | arkhipo-osipovka
# Processing Record 34 of Set 9 | khanbari
# Processing Record 35 of Set 9 | coeur d'alene
# Processing Record 36 of Set 9 | maceio
# Processing Record 37 of Set 9 | ulladulla
# Processing Record 38 of Set 9 | bongor
# Processing Record 39 of Set 9 | remire-montjoly
# Processing Record 40 of Set 9 | itupiranga
# Processing Record 41 of Set 9 | amos
# Processing Record 42 of Set 9 | kapa'a
# Processing Record 43 of Set 9 | hasilpur
# Processing Record 44 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 45 of Set 9 | north bend
# Processing Record 46 of Set 9 | leua
# Processing Record 47 of Set 9 | sillamae
# Processing Record 48 of Set 9 | mahina
# Processing Record 49 of Set 9 | sitka
# Processing Record 0 of Set 10 | swan hill
# Processing Record 1 of Set 10 | karibib
# Processing Record 2 of Set 10 | carutapera
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | brisas de zicatela
# Processing Record 5 of Set 10 | minas de marcona
# Processing Record 6 of Set 10 | gonzalez
# Processing Record 7 of Set 10 | baker city
# Processing Record 8 of Set 10 | yarmouth
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | antofagasta
# Processing Record 11 of Set 10 | grand falls-windsor
# Processing Record 12 of Set 10 | nefta
# Processing Record 13 of Set 10 | torghay
# Processing Record 14 of Set 10 | la palma
# Processing Record 15 of Set 10 | tazovsky
# Processing Record 16 of Set 10 | usogorsk
# Processing Record 17 of Set 10 | cabugao
# Processing Record 18 of Set 10 | kerema
# Processing Record 19 of Set 10 | orsa
# Processing Record 20 of Set 10 | lazaro cardenas
# Processing Record 21 of Set 10 | nykvarn
# Processing Record 22 of Set 10 | kununurra
# Processing Record 23 of Set 10 | tuensang
# Processing Record 24 of Set 10 | akrehamn
# Processing Record 25 of Set 10 | east london
# Processing Record 26 of Set 10 | rongelap
# Processing Record 27 of Set 10 | nagqu
# Processing Record 28 of Set 10 | petrozavodsk
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | itamaraca
# Processing Record 31 of Set 10 | energetik
# Processing Record 32 of Set 10 | carauari
# Processing Record 33 of Set 10 | rio grande
# Processing Record 34 of Set 10 | akkol'
# Processing Record 35 of Set 10 | loukhi
# Processing Record 36 of Set 10 | livny
# Processing Record 37 of Set 10 | phang nga
# Processing Record 38 of Set 10 | ghat
# Processing Record 39 of Set 10 | barillas
# Processing Record 40 of Set 10 | zhangye
# Processing Record 41 of Set 10 | mhasvad
# Processing Record 42 of Set 10 | garachico
# Processing Record 43 of Set 10 | soio
# Processing Record 44 of Set 10 | devonport
# Processing Record 45 of Set 10 | sambava
# Processing Record 46 of Set 10 | rantepao
# Processing Record 47 of Set 10 | tarko-sale
# Processing Record 48 of Set 10 | tamanrasset
# Processing Record 49 of Set 10 | amontada
# Processing Record 0 of Set 11 | agnibilekrou
# Processing Record 1 of Set 11 | krasnokamensk
# Processing Record 2 of Set 11 | morogoro
# Processing Record 3 of Set 11 | mbanza kongo
# Processing Record 4 of Set 11 | daru
# Processing Record 5 of Set 11 | chaman
# Processing Record 6 of Set 11 | lundazi
# Processing Record 7 of Set 11 | gebeit
# Processing Record 8 of Set 11 | souillac
# Processing Record 9 of Set 11 | oruro
# Processing Record 10 of Set 11 | myitkyina
# Processing Record 11 of Set 11 | alzamay
# Processing Record 12 of Set 11 | genoa
# Processing Record 13 of Set 11 | port-vila
# Processing Record 14 of Set 11 | amurzet
# Processing Record 15 of Set 11 | anse-bertrand
# Processing Record 16 of Set 11 | na wa
# Processing Record 17 of Set 11 | jalai nur
# Processing Record 18 of Set 11 | copiapo
# Processing Record 19 of Set 11 | san pedro
# Processing Record 20 of Set 11 | martapura
# Processing Record 21 of Set 11 | kandahar
# Processing Record 22 of Set 11 | grivenskaya
# Processing Record 23 of Set 11 | al muwayh
# Processing Record 24 of Set 11 | machico
# Processing Record 25 of Set 11 | malango
# Processing Record 26 of Set 11 | ad-damazin
# Processing Record 27 of Set 11 | kapit
# Processing Record 28 of Set 11 | rixheim
# Processing Record 29 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 30 of Set 11 | yanbu
# Processing Record 31 of Set 11 | vohipaho
# City not found. Skipping...
# Processing Record 32 of Set 11 | muroto-misakicho
# Processing Record 33 of Set 11 | moose jaw
# Processing Record 34 of Set 11 | knyaze-volkonskoye
# Processing Record 35 of Set 11 | napier
# Processing Record 36 of Set 11 | sudak
# Processing Record 37 of Set 11 | crane
# Processing Record 38 of Set 11 | nanao
# Processing Record 39 of Set 11 | colonia
# Processing Record 40 of Set 11 | ytrebygda
# Processing Record 41 of Set 11 | tangalle
# Processing Record 42 of Set 11 | san mariano
# Processing Record 43 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 44 of Set 11 | longboat key
# Processing Record 45 of Set 11 | nyachera
# Processing Record 46 of Set 11 | kilju
# Processing Record 47 of Set 11 | dalandzadgad
# Processing Record 48 of Set 11 | san antonio
# Processing Record 49 of Set 11 | yankton
# Processing Record 0 of Set 12 | sydney
# Processing Record 1 of Set 12 | shar
# Processing Record 2 of Set 12 | san luis de la loma
# Processing Record 3 of Set 12 | tselinnoye
# Processing Record 4 of Set 12 | beacon square
# Processing Record 5 of Set 12 | itoman
# Processing Record 6 of Set 12 | dois vizinhos
# Processing Record 7 of Set 12 | zakynthos
# Processing Record 8 of Set 12 | boguchany
# Processing Record 9 of Set 12 | bima
# Processing Record 10 of Set 12 | danielskuil
# Processing Record 11 of Set 12 | beltran
# Processing Record 12 of Set 12 | valparaiso
# Processing Record 13 of Set 12 | matonga
# Processing Record 14 of Set 12 | nabire
# Processing Record 15 of Set 12 | xiaoweizhai
# Processing Record 16 of Set 12 | corinto
# Processing Record 17 of Set 12 | gorom-gorom
# Processing Record 18 of Set 12 | usinsk
# Processing Record 19 of Set 12 | esmeraldas
# Processing Record 20 of Set 12 | salalah
# Processing Record 21 of Set 12 | tobelo
# Processing Record 22 of Set 12 | badou
# Processing Record 23 of Set 12 | argo
# Processing Record 24 of Set 12 | branson
# Processing Record 25 of Set 12 | puerto rico
# Processing Record 26 of Set 12 | walvis bay
# Processing Record 27 of Set 12 | shimanovsk
# Processing Record 28 of Set 12 | manismata
# Processing Record 29 of Set 12 | antonio enes
# Processing Record 30 of Set 12 | karonga
# Processing Record 31 of Set 12 | newman
# Processing Record 32 of Set 12 | 'ain el melh
# Processing Record 33 of Set 12 | luis correia
# Processing Record 34 of Set 12 | yamada
# Processing Record 35 of Set 12 | amethi
# Processing Record 36 of Set 12 | puerto aysen
# Processing Record 37 of Set 12 | mata-utu
# Processing Record 38 of Set 12 | castillos
# Processing Record 39 of Set 12 | rehoboth
# Processing Record 40 of Set 12 | codrington
# Processing Record 41 of Set 12 | constitucion
# Processing Record 42 of Set 12 | phongsali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     uturoa -16.7333 -151.4333     27.22        70           0        6.77
# 1  grytviken -54.2811  -36.5092     -3.75        95         100        1.85
# 2   keflavik  64.0049  -22.5624     11.95       100          75        2.06
# 3  adamstown -25.0660 -130.1015     21.78        80          22        9.35
# 4    iqaluit  63.7506  -68.5145      5.85        70          75        3.60
#
#   Country        Date
# 0      PF  1687831331
# 1      GS  1687831158
# 2      IS  1687831331
# 3      PN  1687831332
# 4      CA  1687831332

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data\cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           uturoa -16.7333 -151.4333     27.22        70           0
# 1        grytviken -54.2811  -36.5092     -3.75        95         100
# 2         keflavik  64.0049  -22.5624     11.95       100          75
# 3        adamstown -25.0660 -130.1015     21.78        80          22
# 4          iqaluit  63.7506  -68.5145      5.85        70          75
#
#          Wind Speed Country        Date
# City_ID
# 0              6.77      PF  1687831331
# 1              1.85      GS  1687831158
# 2              2.06      IS  1687831331
# 3              9.35      PN  1687831332
# 4              3.60      CA  1687831332

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x="Lat",y="Max Temp",grid=True,edgecolors='black')
today = date.today()
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title (f"City Max Temperature vs. Latitude({today})")
plt.ylim(-20,40)
plt.tight_layout()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x="Lat", y="Humidity", grid=True,edgecolors='black')
today = date.today()
# Incorporate the other graph properties
plt.xlabel("Latitude")# YOUR CODE HERE
plt.ylabel("Humidity(%)")
plt.title(f"City Latititude vs. Humidity({today})")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x="Lat", y="Cloudiness", grid=True,edgecolors='black')
# Incorporate the other graph properties
plt.xlabel("Latitude")# YOUR CODE HERE
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latititude vs. Cloudiness({today})")
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x="Lat", y="Wind Speed", grid=True,edgecolors='black')
# Incorporate the other graph properties
plt.xlabel("Latitude")# YOUR CODE HERE
plt.ylabel("Wind Speed(m/s)")
plt.title(f"City Latititude vs. Wind Speed({today})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_function(x,y):
    #get the linear regression equation and plot points
    (slope, intercept, r, p, se) = linregress(x,y)
    regress_value= x * slope + intercept
    line_eq= "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(f"The r-value is: {r}")
    
    #plot the data
    plt.scatter(x,y, color='blue')
    plt.plot(x, regress_value, color="red")
    plt.annotate(line_eq,(min(x+5),min(y+5)),fontsize= 15, color='red')
    plt.xlabel('Latitude')
    plt.ylabel(input("ylabel: "))
    plt.title(input("title: ")+ f' ({today})')
    plt.tight_layout()
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                keflavik  64.0049  -22.5624     11.95       100          75
# 4                 iqaluit  63.7506  -68.5145      5.85        70          75
# 5        deutschlandsberg  46.8153   15.2222     20.87        89          75
# 6                 susuman  62.7833  148.1667     25.75        47          29
# 9           mokhsogollokh  61.4681  128.9203     22.28        81         100
#
#          Wind Speed Country        Date
# City_ID
# 2              2.06      IS  1687831331
# 4              3.60      CA  1687831332
# 5              1.79      AT  1687831332
# 6              2.11      RU  1687831333
# 9              0.70      RU  1687831334

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                uturoa -16.7333 -151.4333     27.22        70           0
# 1             grytviken -54.2811  -36.5092     -3.75        95         100
# 3             adamstown -25.0660 -130.1015     21.78        80          22
# 7        puerto natales -51.7236  -72.4875      1.53        99         100
# 8              waitangi -43.9535 -176.5597     12.12        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.77      PF  1687831331
# 1              1.85      GS  1687831158
# 3              9.35      PN  1687831332
# 7              3.01      CL  1687831333
# 8              6.26      NZ  1687831333

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
lin_function(northern_hemi_df['Lat'], northern_hemi_df["Max Temp"])
# Out:
# The r-value is: -0.6086058773105004
# ylabel: Temperature (c)
# title: Temperature vs. Latitude Northern Hemisphere

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
lin_function(southern_hemi_df['Lat'], southern_hemi_df["Max Temp"])
# Out:
# The r-value is: 0.7532653282507599
# ylabel: Temperature (c)
# title: Temperature vs. Latitude Southern Hemisphere

# %% [markdown]
# **Discussion about the linear relationship:** Both charts show a similar pattern where the temperature is colder the further the latitude is from the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
lin_function(northern_hemi_df['Lat'], northern_hemi_df["Humidity"])
# Out:
# The r-value is: -0.1269591802639556
# ylabel: Humidity (%)
# title: Humidity vs. Latitude Northern Hemisphere

# %%
# Southern Hemisphere
# YOUR CODE HERE
lin_function(southern_hemi_df['Lat'], southern_hemi_df["Humidity"])
# Out:
# The r-value is: -0.07516956851421931
# ylabel: Humidity (%)
# title: Humidity vs. Latitude Southern Hemisphere

# %% [markdown]
# **Discussion about the linear relationship:** There is a difference between the regression value for the northern hemisphere and the southern hemisphere.  While the has a more flat distribution showing that there is little correlation between the humidity and latitude, the southern hemisphere shows that there is more of link to humidity and the latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
lin_function(northern_hemi_df['Lat'], northern_hemi_df["Cloudiness"])
# Out:
# The r-value is: 0.007330579905700298
# ylabel: Cloudiness
# title: Cloudiness vs. Latitude Northern Hemisphere

# %%
# Southern Hemisphere
# YOUR CODE HERE
lin_function(southern_hemi_df['Lat'], southern_hemi_df["Cloudiness"])
# Out:
# The r-value is: -0.13454063635213795
# ylabel: Cloudiness
# title: Cloudiness vs. Latitude Southern Hemisphere

# %% [markdown]
# **Discussion about the linear relationship:** The data from the northern hemisphere is quite spreaed out as is shown in the regression line being so flat.  There are a lot of location locations that have iether full cloud coud or no cloud cover at all leading to a slightly negative regression value of -0.012.  The southern hemisphere has a slightly stronger negative correlation with a regression value -0.18. Overall the cloudiness of the cities of the data set is quite spreadout out and does not have much relation with the latitude of the city.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
lin_function(northern_hemi_df['Lat'], northern_hemi_df["Wind Speed"])
# Out:
# The r-value is: -0.001372475891610532
# ylabel: Wind Speed (m/s)
# title: Wind Speed vs. Latitude Northern Hemisphere

# %%
# Southern Hemisphere
# YOUR CODE HERE
lin_function(southern_hemi_df['Lat'], southern_hemi_df["Wind Speed"])
# Out:
# The r-value is: -0.1824067471432146
# ylabel: Wind Speed (m/s)
# title: Wind Speed vs. Latitude Southern Hemisphere

# %% [markdown]
# **Discussion about the linear relationship:** There is not a strong argument for their to be a correlation between the wind speed and latitude of the city.  Both have a slightly negative correlation with the northern hemisphere having a -0.189 regression value compared to the southern hemisphere's -0.031.
